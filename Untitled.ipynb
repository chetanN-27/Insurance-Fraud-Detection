# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import os
pd.set_option('display.max_rows', None)

# %%
ins_claim_info = pd.read_csv('Insurance_Claim_Info_data.csv')


ins_date = pd.read_csv('Insurance_Date_data.csv')

ins_result = pd.read_csv('Insurance_Result_data.csv')

# %%
ins_result.head()
# Out:
#   Claim Number  Claim Amount  Close Amount      Disposition
# 0   Y5VA9KOE89        100.00          0.00             Deny
# 1   P51DOJLR8W        199.99          0.00             Deny
# 2   OUUZFP7EFL        410.00         59.85           Settle
# 3   CGP3L1CCP2        240.00          0.00             Deny
# 4   JDFLPD7J9Z         11.36         11.36  Approve in Full

# %%
ins_result.describe()
# Out:
#         Claim Amount   Close Amount
# count   34110.000000   34110.000000
# mean      717.844178     104.883016
# std      8290.881802    1393.564677
# min         0.000000       0.000000
# 25%        60.000000       0.000000
# 50%       175.000000       0.000000
# 75%       460.000000      75.000000
# max    900000.000000  250000.000000

# %%
ins_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34110 entries, 0 to 34109
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Claim Number  34110 non-null  object
#  1   Claim Amount  34110 non-null  float64
#  2   Close Amount  34110 non-null  float64
#  3   Disposition   34110 non-null  object
# dtypes: float64(2), object(2)
# memory usage: 1.0+ MB

# %%
ins_result['Disposition'].unique()
# Out:
# array(['Deny', 'Settle', 'Approve in Full'], dtype=object)

# %%
print(ins_claim_info.columns)
print(ins_date.columns)
print(ins_result.columns)
# Out:
# Index(['Claim Number', 'City Code', 'City', 'Enterprise Type', 'Claim Type',
#        'Claim Site', 'Product Insured'],
#       dtype='object')
# Index(['Claim Number', 'Incident Date', 'Date Received'], dtype='object')
# Index(['Claim Number', 'Claim Amount', 'Close Amount', 'Disposition'], dtype='object')

# %%
ins_date['Incident Date'] = pd.to_datetime(ins_date['Incident Date'])
ins_date['Date Received'] = pd.to_datetime(ins_date['Date Received'])

mask = (ins_date['Incident Date'] > '2002-01-01') & (ins_date['Incident Date'] <= '2010-01-01')
ins_date = ins_date.loc[mask]
mask = (ins_date['Date Received'] >'2002-01-01') & (ins_date['Date Received'] <= '2010-01-01')
ins_date = ins_date.loc[mask]
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3224\2032978456.py:1: UserWarning: Parsing '21-10-2007' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   ins_date['Incident Date'] = pd.to_datetime(ins_date['Incident Date'])
# C:\Users\PC\AppData\Local\Temp\ipykernel_3224\2032978456.py:1: UserWarning: Parsing '26-05-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   ins_date['Incident Date'] = pd.to_datetime(ins_date['Incident Date'])
# C:\Users\PC\AppData\Local\Temp\ipykernel_3224\2032978456.py:1: UserWarning: Parsing '18-01-2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   ins_date['Incident Date'] = pd.to_datetime(ins_date['Incident Date'])
# ...

# %%
ins_date = ins_date[ins_date['Incident Date'] <= ins_date['Date Received']]
ins_date.shape
# Out:
# (24994, 3)

# %%
# Out:
#   Input In [33]
#     InsureNow is a leading commercial Insurance provider with PAN India presence, The
#                    ^
# SyntaxError: invalid syntax
